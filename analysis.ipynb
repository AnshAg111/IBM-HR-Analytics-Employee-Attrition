# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df['EmployeeCount'].unique()
# Out:
# array([1], dtype=int64)

# %%
df['Over18'].unique()
# Out:
# array(['Y'], dtype=object)

# %%
df['StandardHours'].unique()
# Out:
# array([80], dtype=int64)

# %%
df.drop(columns=['EmployeeCount', 'Over18', 'StandardHours'], inplace=True)

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 1          2  Life Sciences               1
# 1                 8          1  Life Sciences               2
# 2                 2          2          Other               4
# 3                 3          4  Life Sciences               5
# 4                 2          1        Medical               7
#
#    EnvironmentSatisfaction  ... PerformanceRating  RelationshipSatisfaction  \
# 0                        2  ...                 3                         1
# ...

# %%
df['EmployeeNumber'].unique()
# Out:
# array([   1,    2,    4, ..., 2064, 2065, 2068], dtype=int64)

# %%
df['EmployeeNumber'].value_counts()
# Out:
# 1       1
# 1391    1
# 1389    1
# 1387    1
# 1383    1
#        ..
# 659     1
# 657     1
# 656     1
# 655     1
# 2068    1
# Name: EmployeeNumber, Length: 1470, dtype: int64

# %%
df.drop(columns='EmployeeNumber', inplace=True)

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %%
fig, ax = plt.subplots(figsize=(45,20))
sns.boxplot(data=df, width= 0.5,ax=ax,  fliersize=3)
# Out:
# <AxesSubplot: >

# %%
attrition_yes = df[df['Attrition'] == 'Yes']
attrition_gender_counts = attrition_yes['Gender'].value_counts()

plt.figure(figsize=(8, 6))
plt.pie(attrition_gender_counts, labels=attrition_gender_counts.index, autopct='%1.1f%%', colors=['#C53E4A', '#419D9D'])
plt.title('Attrition by Gender', fontsize=16, fontweight='bold')
plt.axis('equal')

plt.show()

# %%
attrition_counts=df['Attrition'].value_counts()
plt.figure(figsize=(8, 6))
plt.pie(attrition_counts, labels=attrition_counts.index, autopct='%1.1f%%', colors=['#C53E4A', '#419D9D'])
plt.title('Attrition distribution', fontsize=16, fontweight='bold')
plt.axis('equal')

plt.show()

# %%
sns.set_theme(style="darkgrid")
sns.set_theme(rc={"figure.figsize":(10, 6)})
ax = sns.countplot(x='BusinessTravel', hue="Attrition", data=df)
plt.title('Attrition Distribution by Business Travel Frequency', fontsize=24)
plt.xlabel('Business Travel', fontsize=18)
plt.show()

# %%
sns.set_theme(style="darkgrid")
sns.set_theme(rc={"figure.figsize":(10, 6)})
ax = sns.countplot(x='Age', hue="Attrition", data=df)
plt.title('Attrition Distribution by Age', fontsize=24)
plt.xlabel('Age', fontsize=18)
plt.show()

# %%
sns.set_theme(style="darkgrid")
sns.set_theme(rc={"figure.figsize":(10, 6)})
ax = sns.countplot(x='EnvironmentSatisfaction', hue="Attrition", data=df)
plt.title('Attrition Distribution by Environment Satisfaction', fontsize=24)
plt.xlabel('Environment Satisfaction', fontsize=18)
plt.show()

# %%
numerical_cols = [feature for feature in df.columns if df[feature].dtype != 'O']
categorical_cols = [feature for feature in df.columns if df[feature].dtype == 'O']

# %%
categorical_cols
# Out:
# ['Attrition',
#  'BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'OverTime']

# %%
categorical_cols.remove('Attrition')
categorical_cols
# Out:
# ['BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'OverTime']

# %%
sns.set_theme(style="darkgrid")
sns.set_theme(rc={"figure.figsize":(16, 6)})
for col in categorical_cols:
    ax = sns.countplot(x=col, hue="Attrition", data=df)
    plt.title(label=f'Attrition Distribution by {col}', fontsize=24)
    plt.xlabel(xlabel=col, fontsize=18)
    plt.show()

# %%
numerical_cols
# Out:
# ['Age',
#  'DailyRate',
#  'DistanceFromHome',
#  'Education',
#  'EnvironmentSatisfaction',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobSatisfaction',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
sns.set_theme(style="darkgrid")
sns.set_theme(rc={"figure.figsize":(10, 6)})
ax = sns.countplot(x='StockOptionLevel', hue="Attrition", data=df)
plt.title('Attrition Distribution by StockOptionLevel', fontsize=24)
plt.xlabel('StockOptionLevel', fontsize=18)
plt.show()

# %%
sns.set_theme(style="darkgrid")
sns.set_theme(rc={"figure.figsize":(10, 6)})
ax = sns.countplot(x='TotalWorkingYears', hue="Attrition", data=df)
plt.title('Attrition Distribution by TotalWorkingYears', fontsize=24)
plt.xlabel('TotalWorkingYears', fontsize=18)
plt.show()

# %%
sns.set_theme(style="darkgrid")
sns.set_theme(rc={"figure.figsize":(10, 6)})
ax = sns.countplot(x='TrainingTimesLastYear', hue="Attrition", data=df)
plt.title('Attrition Distribution by TrainingTimesLastYear', fontsize=24)
plt.xlabel('TrainingTimesLastYear', fontsize=18)
plt.show()

# %%
sns.set_theme(style="darkgrid")
sns.set_theme(rc={"figure.figsize":(10, 6)})
ax = sns.countplot(x='WorkLifeBalance', hue="Attrition", data=df)
plt.title('Attrition Distribution by WorkLifeBalance', fontsize=24)
plt.xlabel('WorkLifeBalance', fontsize=18)
plt.show()

# %%
attrition = df[df['Attrition'] == 'Yes']
no_attrition = df[df['Attrition'] == 'No']

sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.kdeplot(attrition['MonthlyIncome'], label='Attrition', shade=True)
sns.kdeplot(no_attrition['MonthlyIncome'], label='No Attrition', shade=True)

plt.xlabel('Monthly Income')
plt.ylabel('Density')
plt.title('KDE Plot of Monthly Income with respect to Employee Attrition')
plt.legend()
plt.show()

# %%
sns.kdeplot(attrition['PercentSalaryHike'], label='Attrition', shade=True)
sns.kdeplot(no_attrition['PercentSalaryHike'], label='No Attrition', shade=True)

plt.xlabel('PercentSalaryHike')
plt.ylabel('Density')
plt.title('KDE Plot of PercentSalaryHike with respect to Employee Attrition')
plt.legend()
plt.show()

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer 
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

le=LabelEncoder()
# for col in categorical_cols:
df['Attrition']=le.fit_transform(df['Attrition'])

num_pipeline=Pipeline(
    steps=[
        ('imputer',SimpleImputer(strategy='median')),
        ('scaler',MinMaxScaler())
    ]
)
cat_pipeline=Pipeline(
    steps=[
        ('imputer', SimpleImputer(strategy='most_frequent')),
        ('onehotencoder', OneHotEncoder())
    ]
)
df.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2                 1
# 1   49          0               1        279           1                 8
# 2   37          1               2       1373           1                 2
# 3   33          0               1       1392           1                 3
# 4   27          0               2        591           1                 2
#
#    Education  EducationField  EnvironmentSatisfaction  Gender  ...  \
# 0          2               1                        2       0  ...
# 1          1               1                        3       1  ...
# 2          2               4                        4       1  ...
# 3          4               1                        4       0  ...
# 4          1               3                        1       1  ...
#
#    PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %%
preprocessor=ColumnTransformer([
    ('num_pipeline', num_pipeline, numerical_cols),
    ('cat_pipeline', cat_pipeline, categorical_cols)
])

# %%
x=df.drop(labels=['Attrition'], axis=1)
x
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      41               2       1102           2                 1          2
# 1      49               1        279           1                 8          1
# 2      37               2       1373           1                 2          2
# 3      33               1       1392           1                 3          4
# 4      27               2        591           1                 2          1
# ...   ...             ...        ...         ...               ...        ...
# 1465   36               1        884           1                23          2
# 1466   39               2        613           1                 6          1
# 1467   27               2        155           1                 4          3
# 1468   49               1       1023           2                 2          3
# 1469   34               2        628           1                 8          3
#
# ...

# %%
y=df.Attrition
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1470, dtype: int64

# %%
x_train,x_test, y_train,  y_test=train_test_split(x, y, test_size=0.2, random_state=42)
x_train=preprocessor.fit_transform(x_train)
x_test=preprocessor.transform(x_test)
x_train
# Out:
# array([[0.14285714, 0.17790531, 0.71428571, ..., 0.        , 1.        ,
#         0.        ],
#        [0.        , 0.13271162, 0.14285714, ..., 1.        , 1.        ,
#         0.        ],
#        [0.26190476, 0.82137733, 0.67857143, ..., 0.        , 1.        ,
#         0.        ],
#        ...,
#        [0.0952381 , 0.82783357, 0.07142857, ..., 0.        , 0.        ,
#         1.        ],
#        [0.26190476, 0.91535151, 0.42857143, ..., 0.        , 0.        ,
#         1.        ],
#        [0.76190476, 0.11621234, 0.28571429, ..., 0.        , 0.        ,
#         1.        ]])

# %%
fig, ax = plt.subplots(figsize=(45, 20))
sns.boxplot(data=x_train , width= 0.5,ax=ax,  fliersize=3)
# Out:
# <AxesSubplot: >

# %%
y.value_counts()
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import BernoulliNB
models={
    'logistic_regression':LogisticRegression(),
    'support_vector':SVC(probability=True),
    'random_forest':RandomForestClassifier(),
    'decision_tree':DecisionTreeClassifier(),
    'KNN':KNeighborsClassifier(),
    'xgboost':XGBClassifier(n_estimators=1000),
    'naive_bayes':BernoulliNB()
}

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
for i in range(len(models)):
        model=list(models.values())[i]
        model.fit(x_train, y_train)
        y_pred=model.predict(x_test)
        print("Metrics for",list(models.keys())[i])
        print("Accuracy :", accuracy_score(y_test, y_pred))
        print(classification_report(y_test, y_pred))
        print("Confusion Matrix:\n")
        print(confusion_matrix(y_test, y_pred))
# svc=SVC(kernel='linear', probability=True)
# svc.fit(x_train, y_train)
# # print(svc.coef_)
# y_pred=svc.predict(x_test)
# Out:
# Metrics for logistic_regression
# Accuracy : 0.8843537414965986
#               precision    recall  f1-score   support
#
#            0       0.90      0.97      0.94       255
#            1       0.62      0.33      0.43        39
#
#     accuracy                           0.88       294
#    macro avg       0.76      0.65      0.68       294
# weighted avg       0.87      0.88      0.87       294
#
# Confusion Matrix:
#
# [[247   8]
#  [ 26  13]]
# Metrics for support_vector
# Accuracy : 0.891156462585034
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94       255
#            1       0.89      0.21      0.33        39
#
#     accuracy                           0.89       294
#    macro avg       0.89      0.60      0.64       294
# weighted avg       0.89      0.89      0.86       294
#
# Confusion Matrix:
#
# [[254   1]
#  [ 31   8]]
# Metrics for random_forest
# Accuracy : 0.8707482993197279
# ...

# %%
print("highest accuracy is achieved using SVM - 89.1156462585034 % ")
# Out:
# highest accuracy is achieved using SVM - 89.1156462585034 %
